# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
url = "https://github.com/jamcro/shootGaze/blob/master/data/shootingNovice.csv"
#url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
c=pd.read_csv(url)
#gaze_df = pd.read_csv("~jc/Documents/GitHub/shootGaze/data/shootingNovice.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-9f8668f43310> in <module>()
#       5 url = "https://github.com/jamcro/shootGaze/blob/master/data/shootingNovice.csv"
#       6 #url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
# ----> 7 c=pd.read_csv(url)
#       8 #gaze_df = pd.read_csv("~jc/Documents/GitHub/shootGaze/data/shootingNovice.csv")
#
# ...

# %%
gaze_df.head(5)
# Out:
#    Subject  Intervention  Day  Trial  Timer  startTime  finishTime Category  \
# 0        1             0    1      1   7.05      7.685       8.722        B
# 1        1             0    1      1   7.05      8.790       9.419        A
# 2        1             0    1      1   7.05      9.470      13.006        B
# 3        1             0    1      1   7.05     13.074      15.947        C
# 4        1             0    1      1   7.05     15.981      17.834        D
#
#    Position  Distance Shot
# 0       2.0       5.0    0
# 1       1.0       5.0    0
# 2       2.0       5.0    1
# 3       3.0       7.0    0
# 4       4.0       9.0    0

# %%
c.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA
